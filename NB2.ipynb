# %%
import warnings
warnings.filterwarnings('ignore', category=UserWarning)
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils import resample
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV, cross_val_predict
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import numpy as np
import pandas as pd
df1 = pd.read_csv(r"D:\desktop\B\数据\标准化后数据\df1.csv")
df2 = pd.read_excel(r"D:\desktop\B\数据\标准化后数据\df2.xlsx")
df1[['mort', 'CONS','MV','CRRT']] = df1[['mort',  'CONS','MV','CRRT']].astype('category')
df2[['mort',  'CONS','MV','CRRT']] = df2[['mort',  'CONS','MV','CRRT']].astype('category')
selected_features = ["CONS", "LDH", "MV", "AST", "CRRT", "U", "L", "HR", "D.Dimer", "CR", "age", "ALT"]
target = 'mort'
X = df1[selected_features]
y = df1[target]
X_train, X_internal_test, y_train, y_internal_test = train_test_split(X, y, test_size=0.3, random_state=42)
X_external_test = df2[selected_features]
y_external_test = df2[target]

# %%
import numpy as np
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.model_selection import train_test_split, cross_val_predict
from sklearn.utils import resample

RANDOM_SEED = 42

# 定义计算置信区间的函数
def bootstrap_ci(y_true, y_pred, metric_func, n_bootstraps=10000, ci=95, random_state=42):
    rng = np.random.RandomState(random_state)
    bootstrapped_scores = []
    
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    
    for _ in range(n_bootstraps):
        indices = resample(np.arange(len(y_true)), replace=True, random_state=rng)
        score = metric_func(y_true[indices], y_pred[indices])
        bootstrapped_scores.append(score)
    
    lower_bound = np.percentile(bootstrapped_scores, (100-ci)/2)
    upper_bound = np.percentile(bootstrapped_scores, 100-(100-ci)/2)
    return lower_bound, upper_bound

# 初始化 GaussianNB 模型
model_nb = GaussianNB()

best_models_nb = {}

for i in range(1, len(selected_features) + 1):
    current_features = selected_features[:i]
    X_train_current = X_train[current_features]
    X_internal_test_current = X_internal_test[current_features]
    X_external_test_current = X_external_test[current_features]

    # 训练模型
    model_nb.fit(X_train_current, y_train)

    # 使用交叉验证在训练集和内部验证集上进行预测
    y_train_pred_cv = cross_val_predict(model_nb, X_train_current, y_train, cv=10, method='predict')
    y_train_proba_cv = cross_val_predict(model_nb, X_train_current, y_train, cv=10, method='predict_proba')[:, 1]
    
    y_internal_pred_cv = cross_val_predict(model_nb, X_internal_test_current, y_internal_test, cv=10, method='predict')
    y_internal_proba_cv = cross_val_predict(model_nb, X_internal_test_current, y_internal_test, cv=10, method='predict_proba')[:, 1]

    # 进行外部测试集预测
    y_external_pred_nb = model_nb.predict(X_external_test_current)
    y_external_proba_nb = model_nb.predict_proba(X_external_test_current)[:, 1]

    # 计算训练集指标及其置信区间
    train_accuracy = accuracy_score(y_train, y_train_pred_cv)
    train_precision = precision_score(y_train, y_train_pred_cv, average='weighted', zero_division=0)
    train_recall = recall_score(y_train, y_train_pred_cv, average='weighted')
    train_f1 = f1_score(y_train, y_train_pred_cv, average='weighted')
    train_auc = roc_auc_score(y_train, y_train_proba_cv)

    train_ci = {
        'accuracy_ci': bootstrap_ci(y_train, y_train_pred_cv, accuracy_score),
        'precision_ci': bootstrap_ci(y_train, y_train_pred_cv, lambda y_true, y_pred: precision_score(y_true, y_pred, average='weighted', zero_division=0)),
        'recall_ci': bootstrap_ci(y_train, y_train_pred_cv, lambda y_true, y_pred: recall_score(y_true, y_pred, average='weighted')),
        'f1_score_ci': bootstrap_ci(y_train, y_train_pred_cv, lambda y_true, y_pred: f1_score(y_true, y_pred, average='weighted')),
        'auc_ci': bootstrap_ci(y_train, y_train_proba_cv, roc_auc_score)
    }

    # 计算内部验证集指标及其置信区间
    internal_accuracy = accuracy_score(y_internal_test, y_internal_pred_cv)
    internal_precision = precision_score(y_internal_test, y_internal_pred_cv, average='weighted', zero_division=0)
    internal_recall = recall_score(y_internal_test, y_internal_pred_cv, average='weighted')
    internal_f1 = f1_score(y_internal_test, y_internal_pred_cv, average='weighted')
    internal_auc = roc_auc_score(y_internal_test, y_internal_proba_cv)

    internal_ci = {
        'accuracy_ci': bootstrap_ci(y_internal_test, y_internal_pred_cv, accuracy_score),
        'precision_ci': bootstrap_ci(y_internal_test, y_internal_pred_cv, lambda y_true, y_pred: precision_score(y_true, y_pred, average='weighted', zero_division=0)),
        'recall_ci': bootstrap_ci(y_internal_test, y_internal_pred_cv, lambda y_true, y_pred: recall_score(y_true, y_pred, average='weighted')),
        'f1_score_ci': bootstrap_ci(y_internal_test, y_internal_pred_cv, lambda y_true, y_pred: f1_score(y_true, y_pred, average='weighted')),
        'auc_ci': bootstrap_ci(y_internal_test, y_internal_proba_cv, roc_auc_score)
    }

    # 计算外部验证集指标及其置信区间
    external_accuracy = accuracy_score(y_external_test, y_external_pred_nb)
    external_precision = precision_score(y_external_test, y_external_pred_nb, average='weighted', zero_division=0)
    external_recall = recall_score(y_external_test, y_external_pred_nb, average='weighted')
    external_f1 = f1_score(y_external_test, y_external_pred_nb, average='weighted')
    external_auc = roc_auc_score(y_external_test, y_external_proba_nb)

    external_ci = {
        'accuracy_ci': bootstrap_ci(y_external_test, y_external_pred_nb, accuracy_score),
        'precision_ci': bootstrap_ci(y_external_test, y_external_pred_nb, lambda y_true, y_pred: precision_score(y_true, y_pred, average='weighted', zero_division=0)),
        'recall_ci': bootstrap_ci(y_external_test, y_external_pred_nb, lambda y_true, y_pred: recall_score(y_true, y_pred, average='weighted')),
        'f1_score_ci': bootstrap_ci(y_external_test, y_external_pred_nb, lambda y_true, y_pred: f1_score(y_true, y_pred, average='weighted')),
        'auc_ci': bootstrap_ci(y_external_test, y_external_proba_nb, roc_auc_score)
    }

    # 保存结果
    best_models_nb[i] = {
        'features': current_features,
        'train_metrics': {
            'accuracy': train_accuracy,
            'precision': train_precision,
            'recall': train_recall,
            'f1_score': train_f1,
            'auc': train_auc
        },
        'train_ci': train_ci,
        'internal_metrics': {
            'accuracy': internal_accuracy,
            'precision': internal_precision,
            'recall': internal_recall,
            'f1_score': internal_f1,
            'auc': internal_auc
        },
        'internal_ci': internal_ci,
        'external_metrics': {
            'accuracy': external_accuracy,
            'precision': external_precision,
            'recall': external_recall,
            'f1_score': external_f1,
            'auc': external_auc
        },
        'external_ci': external_ci
    }

# 输出结果
for i, results in best_models_nb.items():
    print(f"\nModel with top {i} features: {results['features']}")

    print("Training Set Metrics:")
    for metric, value in results['train_metrics'].items():
        print(f"{metric.capitalize()}: {value:.4f} 置信区间: {results['train_ci'][metric+'_ci'][0]:.4f}-{results['train_ci'][metric+'_ci'][1]:.4f}")

    print("Internal Validation Set Metrics:")
    for metric, value in results['internal_metrics'].items():
        print(f"{metric.capitalize()}: {value:.4f} 置信区间: {results['internal_ci'][metric+'_ci'][0]:.4f}-{results['internal_ci'][metric+'_ci'][1]:.4f}")

    print("External Validation Set Metrics:")
    for metric, value in results['external_metrics'].items():
        print(f"{metric.capitalize()}: {value:.4f} 置信区间: {results['external_ci'][metric+'_ci'][0]:.4f}-{results['external_ci'][metric+'_ci'][1]:.4f}")
# Out:
# Model with top 1 features: ['CONS']
# Training Set Metrics:
# Accuracy: 0.8676 置信区间: 0.8186-0.9118
# Precision: 0.8760 置信区间: 0.8312-0.9185
# Recall: 0.8676 置信区间: 0.8186-0.9118
# F1_score: 0.8706 置信区间: 0.8235-0.9134
# Auc: 0.7913 置信区间: 0.7010-0.8715
# Internal Validation Set Metrics:
# Accuracy: 0.7500 置信区间: 0.6591-0.8409
# Precision: 0.8013 置信区间: 0.7206-0.8782
# Recall: 0.7500 置信区间: 0.6591-0.8409
# F1_score: 0.7621 置信区间: 0.6756-0.8452
# Auc: 0.6706 置信区间: 0.5288-0.8027
# External Validation Set Metrics:
# Accuracy: 0.8558 置信区间: 0.7885-0.9231
# Precision: 0.8503 置信区间: 0.7767-0.9215
# Recall: 0.8558 置信区间: 0.7885-0.9231
# F1_score: 0.8476 置信区间: 0.7696-0.9183
# Auc: 0.7628 置信区间: 0.6643-0.8610
#
# Model with top 2 features: ['CONS', 'LDH']
# Training Set Metrics:
# Accuracy: 0.8676 置信区间: 0.8186-0.9118
# Precision: 0.8820 置信区间: 0.8394-0.9214
# Recall: 0.8676 置信区间: 0.8186-0.9118
# F1_score: 0.8720 置信区间: 0.8265-0.9139
# Auc: 0.8629 置信区间: 0.7841-0.9290
# Internal Validation Set Metrics:
# Accuracy: 0.8182 置信区间: 0.7273-0.8977
# Precision: 0.8106 置信区间: 0.7218-0.8950
# Recall: 0.8182 置信区间: 0.7273-0.8977
# F1_score: 0.8053 置信区间: 0.7081-0.8899
# Auc: 0.8151 置信区间: 0.6916-0.9168
# External Validation Set Metrics:
# Accuracy: 0.8750 置信区间: 0.8077-0.9327
# Precision: 0.8711 置信区间: 0.8034-0.9343
# Recall: 0.8750 置信区间: 0.8077-0.9327
# F1_score: 0.8703 置信区间: 0.7986-0.9321
# Auc: 0.8393 置信区间: 0.7133-0.9471
#
# Model with top 3 features: ['CONS', 'LDH', 'MV']
# Training Set Metrics:
# Accuracy: 0.8627 置信区间: 0.8137-0.9069
# Precision: 0.8672 置信区间: 0.8197-0.9129
# Recall: 0.8627 置信区间: 0.8137-0.9069
# F1_score: 0.8646 置信区间: 0.8162-0.9090
# Auc: 0.8731 置信区间: 0.7990-0.9362
# Internal Validation Set Metrics:
# Accuracy: 0.8409 置信区间: 0.7614-0.9091
# Precision: 0.8375 置信区间: 0.7589-0.9165
# Recall: 0.8409 置信区间: 0.7614-0.9091
# F1_score: 0.8387 置信区间: 0.7575-0.9108
# Auc: 0.8281 置信区间: 0.7056-0.9304
# External Validation Set Metrics:
# Accuracy: 0.9135 置信区间: 0.8558-0.9615
# Precision: 0.9163 置信区间: 0.8625-0.9633
# Recall: 0.9135 置信区间: 0.8558-0.9615
# F1_score: 0.9086 置信区间: 0.8446-0.9608
# Auc: 0.8713 置信区间: 0.7509-0.9716
#
# Model with top 4 features: ['CONS', 'LDH', 'MV', 'AST']
# Training Set Metrics:
# Accuracy: 0.8824 置信区间: 0.8382-0.9265
# Precision: 0.8788 置信区间: 0.8310-0.9247
# Recall: 0.8824 置信区间: 0.8382-0.9265
# F1_score: 0.8795 置信区间: 0.8312-0.9236
# Auc: 0.8805 置信区间: 0.8055-0.9439
# Internal Validation Set Metrics:
# Accuracy: 0.8523 置信区间: 0.7727-0.9205
# Precision: 0.8505 置信区间: 0.7754-0.9222
# Recall: 0.8523 置信区间: 0.7727-0.9205
# F1_score: 0.8513 置信区间: 0.7739-0.9210
# Auc: 0.8281 置信区间: 0.7064-0.9277
# External Validation Set Metrics:
# Accuracy: 0.9038 置信区间: 0.8462-0.9519
# Precision: 0.9019 置信区间: 0.8418-0.9551
# Recall: 0.9038 置信区间: 0.8462-0.9519
# F1_score: 0.9010 置信区间: 0.8372-0.9526
# Auc: 0.8555 置信区间: 0.7234-0.9656
#
# Model with top 5 features: ['CONS', 'LDH', 'MV', 'AST', 'CRRT']
# Training Set Metrics:
# Accuracy: 0.8775 置信区间: 0.8284-0.9216
# Precision: 0.8766 置信区间: 0.8295-0.9208
# Recall: 0.8775 置信区间: 0.8284-0.9216
# F1_score: 0.8770 置信区间: 0.8290-0.9203
# Auc: 0.8956 置信区间: 0.8273-0.9511
# Internal Validation Set Metrics:
# Accuracy: 0.8182 置信区间: 0.7386-0.8977
# Precision: 0.8235 置信区间: 0.7438-0.9010
# Recall: 0.8182 置信区间: 0.7386-0.8977
# F1_score: 0.8204 置信区间: 0.7385-0.8971
# Auc: 0.8304 置信区间: 0.7119-0.9282
# External Validation Set Metrics:
# Accuracy: 0.8846 置信区间: 0.8173-0.9423
# Precision: 0.8821 置信区间: 0.8151-0.9427
# Recall: 0.8846 置信区间: 0.8173-0.9423
# F1_score: 0.8792 置信区间: 0.8077-0.9412
# Auc: 0.8590 置信区间: 0.7275-0.9698
#
# Model with top 6 features: ['CONS', 'LDH', 'MV', 'AST', 'CRRT', 'U']
# Training Set Metrics:
# Accuracy: 0.8725 置信区间: 0.8235-0.9167
# Precision: 0.8745 置信区间: 0.8273-0.9189
# Recall: 0.8725 置信区间: 0.8235-0.9167
# F1_score: 0.8734 置信区间: 0.8253-0.9164
# Auc: 0.9073 置信区间: 0.8470-0.9553
# Internal Validation Set Metrics:
# Accuracy: 0.8068 置信区间: 0.7273-0.8864
# Precision: 0.8155 置信区间: 0.7337-0.8963
# Recall: 0.8068 置信区间: 0.7273-0.8864
# F1_score: 0.8102 置信区间: 0.7273-0.8878
# Auc: 0.8372 置信区间: 0.7274-0.9276
# External Validation Set Metrics:
# Accuracy: 0.8846 置信区间: 0.8173-0.9423
# Precision: 0.8821 置信区间: 0.8151-0.9427
# Recall: 0.8846 置信区间: 0.8173-0.9423
# F1_score: 0.8792 置信区间: 0.8077-0.9412
# Auc: 0.8886 置信区间: 0.7797-0.9784
#
# Model with top 7 features: ['CONS', 'LDH', 'MV', 'AST', 'CRRT', 'U', 'L']
# Training Set Metrics:
# Accuracy: 0.8725 置信区间: 0.8235-0.9167
# Precision: 0.8745 置信区间: 0.8273-0.9189
# Recall: 0.8725 置信区间: 0.8235-0.9167
# F1_score: 0.8734 置信区间: 0.8253-0.9164
# Auc: 0.9073 置信区间: 0.8471-0.9552
# Internal Validation Set Metrics:
# Accuracy: 0.8182 置信区间: 0.7386-0.8977
# Precision: 0.8299 置信区间: 0.7510-0.9055
# Recall: 0.8182 置信区间: 0.7386-0.8977
# F1_score: 0.8222 置信区间: 0.7424-0.8983
# Auc: 0.8486 置信区间: 0.7467-0.9325
# External Validation Set Metrics:
# Accuracy: 0.8750 置信区间: 0.8077-0.9327
# Precision: 0.8711 置信区间: 0.8023-0.9343
# Recall: 0.8750 置信区间: 0.8077-0.9327
# F1_score: 0.8703 置信区间: 0.7981-0.9330
# Auc: 0.8866 置信区间: 0.7808-0.9744
#
# Model with top 8 features: ['CONS', 'LDH', 'MV', 'AST', 'CRRT', 'U', 'L', 'HR']
# Training Set Metrics:
# Accuracy: 0.8627 置信区间: 0.8137-0.9069
# Precision: 0.8609 置信区间: 0.8104-0.9080
# Recall: 0.8627 置信区间: 0.8137-0.9069
# F1_score: 0.8617 置信区间: 0.8106-0.9072
# Auc: 0.9100 置信区间: 0.8498-0.9579
# Internal Validation Set Metrics:
# Accuracy: 0.8182 置信区间: 0.7386-0.8977
# Precision: 0.8299 置信区间: 0.7510-0.9055
# Recall: 0.8182 置信区间: 0.7386-0.8977
# F1_score: 0.8222 置信区间: 0.7424-0.8983
# Auc: 0.8451 置信区间: 0.7407-0.9308
# External Validation Set Metrics:
# Accuracy: 0.8750 置信区间: 0.8077-0.9327
# Precision: 0.8711 置信区间: 0.8023-0.9343
# Recall: 0.8750 置信区间: 0.8077-0.9327
# F1_score: 0.8703 置信区间: 0.7981-0.9330
# Auc: 0.8738 置信区间: 0.7547-0.9701
#
# Model with top 9 features: ['CONS', 'LDH', 'MV', 'AST', 'CRRT', 'U', 'L', 'HR', 'D.Dimer']
# Training Set Metrics:
# Accuracy: 0.8578 置信区间: 0.8088-0.9020
# Precision: 0.8569 置信区间: 0.8057-0.9049
# Recall: 0.8578 置信区间: 0.8088-0.9020
# F1_score: 0.8573 置信区间: 0.8058-0.9028
# Auc: 0.9065 置信区间: 0.8468-0.9547
# Internal Validation Set Metrics:
# Accuracy: 0.8068 置信区间: 0.7273-0.8864
# Precision: 0.8155 置信区间: 0.7345-0.8965
# Recall: 0.8068 置信区间: 0.7273-0.8864
# F1_score: 0.8102 置信区间: 0.7273-0.8877
# Auc: 0.8783 置信区间: 0.7952-0.9471
# External Validation Set Metrics:
# Accuracy: 0.8750 置信区间: 0.8077-0.9327
# Precision: 0.8711 置信区间: 0.8023-0.9343
# Recall: 0.8750 置信区间: 0.8077-0.9327
# F1_score: 0.8703 置信区间: 0.7981-0.9330
# Auc: 0.8738 置信区间: 0.7552-0.9707
#
# Model with top 10 features: ['CONS', 'LDH', 'MV', 'AST', 'CRRT', 'U', 'L', 'HR', 'D.Dimer', 'CR']
# Training Set Metrics:
# Accuracy: 0.8578 置信区间: 0.8088-0.9020
# Precision: 0.8589 置信区间: 0.8079-0.9061
# Recall: 0.8578 置信区间: 0.8088-0.9020
# F1_score: 0.8583 置信区间: 0.8073-0.9035
# Auc: 0.9004 置信区间: 0.8369-0.9518
# Internal Validation Set Metrics:
# Accuracy: 0.7955 置信区间: 0.7045-0.8750
# Precision: 0.8080 置信区间: 0.7265-0.8897
# Recall: 0.7955 置信区间: 0.7045-0.8750
# F1_score: 0.8000 置信区间: 0.7145-0.8777
# Auc: 0.8646 置信区间: 0.7762-0.9384
# External Validation Set Metrics:
# Accuracy: 0.9038 置信区间: 0.8462-0.9615
# Precision: 0.9021 置信区间: 0.8426-0.9611
# Recall: 0.9038 置信区间: 0.8462-0.9615
# F1_score: 0.9025 置信区间: 0.8417-0.9603
# Auc: 0.8792 置信区间: 0.7576-0.9803
#
# Model with top 11 features: ['CONS', 'LDH', 'MV', 'AST', 'CRRT', 'U', 'L', 'HR', 'D.Dimer', 'CR', 'age']
# Training Set Metrics:
# Accuracy: 0.8578 置信区间: 0.8088-0.9020
# Precision: 0.8589 置信区间: 0.8079-0.9061
# Recall: 0.8578 置信区间: 0.8088-0.9020
# F1_score: 0.8583 置信区间: 0.8073-0.9035
# Auc: 0.9104 置信区间: 0.8558-0.9546
# Internal Validation Set Metrics:
# Accuracy: 0.8182 置信区间: 0.7386-0.8977
# Precision: 0.8235 置信区间: 0.7438-0.9037
# Recall: 0.8182 置信区间: 0.7386-0.8977
# F1_score: 0.8204 置信区间: 0.7382-0.8973
# Auc: 0.8724 置信区间: 0.7889-0.9421
# External Validation Set Metrics:
# Accuracy: 0.9038 置信区间: 0.8462-0.9615
# Precision: 0.9021 置信区间: 0.8426-0.9611
# Recall: 0.9038 置信区间: 0.8462-0.9615
# F1_score: 0.9025 置信区间: 0.8417-0.9603
# Auc: 0.8826 置信区间: 0.7654-0.9808
#
# Model with top 12 features: ['CONS', 'LDH', 'MV', 'AST', 'CRRT', 'U', 'L', 'HR', 'D.Dimer', 'CR', 'age', 'ALT']
# Training Set Metrics:
# Accuracy: 0.8529 置信区间: 0.8039-0.8971
# Precision: 0.8552 置信区间: 0.8044-0.9023
# Recall: 0.8529 置信区间: 0.8039-0.8971
# F1_score: 0.8540 置信区间: 0.8029-0.8993
# Auc: 0.9075 置信区间: 0.8534-0.9519
# Internal Validation Set Metrics:
# Accuracy: 0.8182 置信区间: 0.7386-0.8977
# Precision: 0.8235 置信区间: 0.7438-0.9037
# Recall: 0.8182 置信区间: 0.7386-0.8977
# F1_score: 0.8204 置信区间: 0.7382-0.8973
# Auc: 0.8623 置信区间: 0.7773-0.9349
# External Validation Set Metrics:
# Accuracy: 0.9038 置信区间: 0.8462-0.9615
# Precision: 0.9021 置信区间: 0.8426-0.9611
# Recall: 0.9038 置信区间: 0.8462-0.9615
# F1_score: 0.9025 置信区间: 0.8417-0.9603
# Auc: 0.8750 置信区间: 0.7563-0.9732

# %%
import pandas as pd
import os

# 设置输出文件夹路径
output_folder = r"D:\desktop\B\结果\表格\内部外部验证结果"
os.makedirs(output_folder, exist_ok=True)  # 确保输出文件夹存在

# 用于存储结果的列表
output_data = []

# 遍历模型结果并将其组织为字典
for i, results in best_models_nb.items():
    model_name = f"Model with top {i} features"
    for metric in results['train_metrics'].keys():
        output_data.append({
            'Model': model_name,
            'Dataset': 'Training Set',
            'Metric': metric.capitalize(),
            'Value': results['train_metrics'][metric],
            'Confidence Interval': f"{results['train_ci'][metric+'_ci'][0]:.4f}-{results['train_ci'][metric+'_ci'][1]:.4f}"
        })
        output_data.append({
            'Model': model_name,
            'Dataset': 'Internal Validation Set',
            'Metric': metric.capitalize(),
            'Value': results['internal_metrics'][metric],
            'Confidence Interval': f"{results['internal_ci'][metric+'_ci'][0]:.4f}-{results['internal_ci'][metric+'_ci'][1]:.4f}"
        })
        output_data.append({
            'Model': model_name,
            'Dataset': 'External Validation Set',
            'Metric': metric.capitalize(),
            'Value': results['external_metrics'][metric],
            'Confidence Interval': f"{results['external_ci'][metric+'_ci'][0]:.4f}-{results['external_ci'][metric+'_ci'][1]:.4f}"
        })

# 将列表转换为 DataFrame
output_df = pd.DataFrame(output_data)

# 设置文件名
output_file = os.path.join(output_folder, "NB_Results.xlsx")

# 将 DataFrame 保存为 Excel 文件
output_df.to_excel(output_file, index=False)

print(f"结果已保存至：{output_file}")
# Out:
# 结果已保存至：D:\desktop\B\结果\表格\内部外部验证结果\NB_Results.xlsx
